# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# **Project:** Data Minining Project for  X company

# %% [markdown]
# The CRISP-DM Framework
#
#
# The CRISP-DM methodology provides a structured approach to planning a data mining project. It is a robust and well-proven methodology.
# * Business understanding (BU): Determine Business Objectives, Assess Situation, Determine Data Mining Goals, Produce Project Plan
#
# * Data understanding (DU): Collect Initial Data, Describe Data, Explore Data, Verify Data Quality
#
# * Data preparation (DP): Select Data, Clean Data, Construct Data, Integrate Data
#
# * Modeling (M): Select modeling technique, Generate Test Design, Build Model, Assess Model
# *  Evaluation (E): Evaluate Results, Review Process, Determine Next Steps
# *  Deployment (D): Plan Deployment, Plan Monitoring and Maintenance, Produce Final Report, Review Project
#
#
# References:
#
# [What is the CRISP-DM methodology?](https://www.sv-europe.com/crisp-dm-methodology/)
#
# [Introduction to CRISP DM Framework for Data Science and Machine Learning](https://www.linkedin.com/pulse/chapter-1-introduction-crisp-dm-framework-data-science-anshul-roy/)

# %% [markdown]
# **Data Set**
# ### The data is for company X which is trying to control attrition.
# ### There are two sets of data: "Existing employees" and "Employees who have left". The following attributes are available for every employee.
#
#
# *   Satisfaction Level
#
# *   Last evaluation
#
# *   Number of projects
#
# *   Average monthly hours
#
# *   Time spent at the company
# *   Whether they have had a work accident
#
#
# *  Whether they have had a promotion in the last 5 years
#
#
# *   Departments (column sales)
#
#
# *   Salary
#
#
# *  Whether the employee has left

# %% [markdown]
# **Your Role**
#
#
# *   As data science team member X company asked you to answer this two questions.
# *  What type of employees is leaving?
#
# *   Determine which employees are prone to leave next.

# %% [markdown]
# Business Understanding
#
# ---
#
# This step mostly focuses on understanding the Business in all the different aspects. It follows the below different steps.
#
#
#
#
# * Identify the goal and frame the business problem.
# * Prepare Analytical Goal i.e. what type of performance metric and loss function to use
# * Gather information on resource, constraints, assumptions, risks etc
# *   Prepare Work Flow Chart

# %% [markdown]
# ### Write the main objectives of this project in your words?
# minimum of 100 characters

# %%
main_objectives='''The main objective of this study is to evaluate the possibility of employees leaving the company within a given period of time 
based on their satisfaction level with working conditions offered by the company.
'''

# %%
assert len(main_objectives) > 100 
### BEGIN HIDDEN TESTS
assert len(main_objectives) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### Outline the different data analysis steps you will follow to carry out the project

# %%
dm_outline = '''To analyze this data, I will first begin by evaluating the different attributes of the employees and how they influence whetherthey have left the company or not. 
I would perform a classification analysis using support vector, Logistic regression, K-nearest neighbors, random forest classifier and Multi-layer perceptron classifier machine algorithm. 
I will then perroform a grid search validation for all the algorithms to obtain the best set of parameters through hyperparameter tuning. 
I would then deploy the models with the best set of parameters and observe their performance.
'''

# %%
assert len(dm_outline) > 100 
### BEGIN HIDDEN TESTS
assert len(dm_outline) > 70 
### END HIDDEN TESTS

# %% [markdown]
# ### What metrics will you use to measure the performance of your data analysis model?
# Write the equations of the metrics here

# %% [markdown]
# e.g. Precision = $\frac{TP}{(TP + FP)}$
# * Recall
# * Jaccard Index

# %% [markdown]
# Why do you choose these metrics? minimum of 100 characters

# %%
why_metrics = '''I will prefer Precision because quantifies the number of positive class predictions that actually belong to the positive class which helps us to avoid type I error.
Precision has over the years proven to be the best model evaluation metrics for classification taks and based on that record, I will also deploy it for my case
'''

# %%
assert len(why_metrics) > 100 
### BEGIN HIDDEN TESTS
assert len(why_metrics) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### How would you know if your data analysis work is a success or not?
# minimum of 100 characters

# %%
how_success = '''I will evaluate the accuracy of my analysis by plotting the confusion matrix to evaluate the evaluation metrics highlited above.
 I will check if my True positive rate is good enough to validate or invalidate the metrics and then finally make a model selection based on these results
'''

# %%
assert len(how_success) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ## What kind of challenges do you expect in your analysis?
# List at least 3 challenges

# %%
challenge_text ='''I actually expect to encounter a range of challenges in my quest to provide an explicit solution to company X based on the complexity of this machine learning task.
* Dealing with missing data
* The process of data selection and validation
* Feature ingineering may not be very direct as there are very many variables
'''

# %%
assert len(challenge_text) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# <h2>Using the processed twitter data from yesterday's challenge</h2>.
#
#
# - Form a new data frame (named `cleanTweet`), containing columns $\textbf{clean-text}$ and $\textbf{polarity}$.
#
# - Write a function `text_category` that takes a value `p` and returns, depending on the value of p, a string `'positive'`, `'negative'` or `'neutral'`.
#
# - Apply this function (`text_category`) on the $\textbf{polarity}$ column of `cleanTweet` in 1 above to form a new column called $\textbf{score}$ in `cleanTweet`.
#
# - Visualize The $\textbf{score}$ column using piechart and barchart
#
# <h5>Now we want to build a classification model on the clean tweet following the steps below:</h5>
#
# * Remove rows from `cleanTweet` where $\textbf{polarity}$ $= 0$ (i.e where $\textbf{score}$ = Neutral) and reset the frame index.
# * Construct a column $\textbf{scoremap}$ Use the mapping {'positive':1, 'negative':0} on the $\textbf{score}$ column
# * Create feature and target variables `(X,y)` from $\textbf{clean-text}$ and $\textbf{scoremap}$ columns respectively.
# * Use `train_test_split` function to construct `(X_train, y_train)` and `(X_test, y_test)` from `(X,y)`
#
# * Build an `SGDClassifier` model from the vectorize train text data. Use `CountVectorizer()` with a $\textit{trigram}$ parameter.
#
# * Evaluate your model on the test data.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2b88aa39-ab76-48f1-824d-9dc0439f134e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b88aa39-ab76-48f1-824d-9dc0439f134e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving output.csv to output (1).csv

# %%
df = pd.read_csv('output.csv')
df = df[['original_text']]
df.head()
# Out:
#                                        original_text
# 0  Giving forth life is becoming a burden in Keny...
# 1  Teenmaar - 26cr\nPanja - 32.5cr\nGabbarsingh -...
# 2  Rei chintu 2013 lo Vachina Ad Nizam ne 2018 lo...
# 3  Today is World Day to Combat #Desertification ...
# 4  Hearing #GregHunt say he's confident vaccines ...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_Txt(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\\[.*?\\]', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', ' ', text)
    text = re.sub(r'@[A-Za-z0-9]+', ' ', text)
    text = re.sub(r'\n', ' ', text)
    return text

# %%
df['original_text'] = df['original_text'].str.replace("[^a-zA-Z]"," ")

# %%
df['original_text'] = df['original_text'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))

# %%
#Clean the dataFrame
df['original_text'] = df['original_text'].apply(clean_Txt)
df
# Out:
#                                           original_text
# 0     giving forth life becoming burden kenya this m...
# 1     teenmaar panja gabbarsingh khaleja kuda varaku...
# 2     chintu vachina nizam kottaru films pattinndhi ...
# 3     today world combat desertification drought res...
# 4     hearing greghunt confident vaccines will deliv...
# ...                                                 ...
# 5616  lambie voted against medivac carbon protecting...
# 5617  idhi bathuku most records nizam from asvr agad...
# 5618  welkin moon giveaway finally have money gotta ...
# 5619  manam chesina daaniki kuda elevation istadu ve...
# 5620  this first time seen government media least pr...
#
# [5621 rows x 1 columns]

# %%
from textblob import TextBlob
# Function for polarity and subjectivity

def Getsubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

def Getpolarity(text):
  return TextBlob(text).sentiment.polarity

#Create new columns
df['Subjectivity'] = df['original_text'].apply(Getsubjectivity)
df['Polarity'] = df['original_text'].apply(Getpolarity)
df
# Out:
#                                           original_text  Subjectivity  Polarity
# 0     giving forth life becoming burden kenya this m...      0.697222 -0.113889
# 1     teenmaar panja gabbarsingh khaleja kuda varaku...      0.000000  0.000000
# 2     chintu vachina nizam kottaru films pattinndhi ...      0.000000  0.000000
# 3     today world combat desertification drought res...      0.650000  0.250000
# 4     hearing greghunt confident vaccines will deliv...      0.833333  0.500000
# ...                                                 ...           ...       ...
# 5616  lambie voted against medivac carbon protecting...      0.000000  0.000000
# 5617  idhi bathuku most records nizam from asvr agad...      0.500000  0.500000
# 5618  welkin moon giveaway finally have money gotta ...      0.600000  0.123333
# 5619  manam chesina daaniki kuda elevation istadu ve...      0.000000  0.000000
# 5620  this first time seen government media least pr...      0.406667  0.130000
#
# [5621 rows x 3 columns]

# %%
#Vusualizations Plot World Cloud
plt.figure(figsize = (12,10))
from wordcloud import WordCloud
allwords = ' '.join( [twts for twts in df['original_text']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21 , max_font_size = 119).generate(allwords)


plt.imshow(wordCloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
#Function to compute negative, neutral and positive analysis
def Getanalysis(p):
  if p< 0:
    return 'Negative'
  elif p==0:
    return 'Neutral'
  else:
    return 'Positive'


df['scoremap'] = df['Polarity'].apply(Getanalysis)
df
# Out:
#                                           original_text  ...  scoremap
# 0     giving forth life becoming burden kenya this m...  ...  Negative
# 1     teenmaar panja gabbarsingh khaleja kuda varaku...  ...   Neutral
# 2     chintu vachina nizam kottaru films pattinndhi ...  ...   Neutral
# 3     today world combat desertification drought res...  ...  Positive
# 4     hearing greghunt confident vaccines will deliv...  ...  Positive
# ...                                                 ...  ...       ...
# 5616  lambie voted against medivac carbon protecting...  ...   Neutral
# 5617  idhi bathuku most records nizam from asvr agad...  ...  Positive
# 5618  welkin moon giveaway finally have money gotta ...  ...  Positive
# 5619  manam chesina daaniki kuda elevation istadu ve...  ...   Neutral
# 5620  this first time seen government media least pr...  ...  Positive
#
# [5621 rows x 4 columns]

# %%
# Print all of the positive tweets
j = 1
sortedDf = df.sort_values(by=['Polarity'])
for i in range(0,sortedDf.shape[0]):
  if (sortedDf['scoremap'][i]=='Positive'):
     print(str(j) + ') '+sortedDf['original_text'][i])
     print()
     j = j+1
     if j == 5:
       break;
# Out:
# 1) today world combat desertification drought restoring degraded land brings resilience jobs food security helps biodiversity recover slows climatechange locking away carbon critical lifting many poverty undpclimate undpinpng
#
# 2) hearing greghunt confident vaccines will delivered like hearing morrison reducing carbon emissions auspol
#
# 3) today world combat desertification drought restoring degraded land brings resilience jobs food security helps biodiversity recover slows climatechange locking away carbon critical lifting many poverty undpclimate undpinpng
#
# 4) deployment carbon technologies need taken massive scale especially msmes electric mobility should more aggressively pushed shri singh union power minister india ddnewslive india

# %%
# Print the negative tweets
j = 1 
sortedDF = df.sort_values(by = ['Polarity'],ascending = 'False')
for i in range(0 , sortedDF.shape[0]):
  if (sortedDF['scoremap'][i] ==  'Negative'):
    print(str(j) + ') '+ sortedDF['original_text'][i])
    print()
    j=j+1
    if j==5:
      break;
# Out:
# 1) giving forth life becoming burden kenya this mother gave birth babies having hard time meeting their nutritional needs baby formula expensive turn bundles tears giving hand mpesa douglas nyaoko https dnpzmtvwji
#
# 2) office wise base tier kindha consider cheyachhu office fanbase anyday tarak charan office records kuda mana chiru mafia gurinchi telisindhe mutual tarak medha abusive tweets kuda vesa manofmassesntr
#
# 3) office wise base tier kindha consider cheyachhu office fanbase anyday tarak charan office records kuda mana chiru mafia gurinchi telisindhe mutual tarak medha abusive tweets kuda vesa manofmassesntr
#
# 4) swedish firm lundin selling carbon neutral will counted carbon neutral from exploration development called scope emissions emissions caused final scope emissions included https qigt https mrgbqaxgc

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
for i in range(0,df.shape[0]):
  plt.scatter(df['Polarity'][i],df['Subjectivity'][i],color = 'red')

plt.title('Sentiment Analysis')
plt.xlabel('polarity')
plt.xlabel('Subjectivity')
plt.show()

# %%
#Percentage of positive tweets
ptweets = df[df.scoremap == 'Positive']
ptweets = ptweets['original_text']

print(round( (ptweets.shape[0]/df.shape[0])*100, 1) ,"%")
# Out:
# 43.1 %

# %%
ntweets = df[df.scoremap == 'Negative']
ntweets = ntweets['original_text']

print( round( (ntweets.shape[0]/df.shape[0])*100, 1),"%")
# Out:
# 17.2 %

# %%
nutweets = df[df.scoremap == 'Neutral']
nutweets = nutweets['original_text']

print( round( (nutweets.shape[0]/df.shape[0])*100, 1), "%")
# Out:
# 39.7 %

# %%
#Show the value counts
df['scoremap'].value_counts()

#plot and visualize the counts
plt.figure(figsize=(12,10))
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.xlabel('Counts')
df['scoremap'].value_counts().plot(kind ='bar')
plt.show()

# %%
#plot and visualize the counts
plt.figure(figsize=(12,10))
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.xlabel('Counts')
df['scoremap'].value_counts().plot(kind ='pie')
plt.show()

# %%
df.head()
# Out:
#                                        original_text  ...  scoremap
# 0  giving forth life becoming burden kenya this m...  ...  Negative
# 1  teenmaar panja gabbarsingh khaleja kuda varaku...  ...   Neutral
# 2  chintu vachina nizam kottaru films pattinndhi ...  ...   Neutral
# 3  today world combat desertification drought res...  ...  Positive
# 4  hearing greghunt confident vaccines will deliv...  ...  Positive
#
# [5 rows x 4 columns]

# %%
# Individual words considered as tokens
tokenized_tweet = df['original_text'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [giving, forth, life, becoming, burden, kenya,...
# 1    [teenmaar, panja, gabbarsingh, khaleja, kuda, ...
# 2    [chintu, vachina, nizam, kottaru, films, patti...
# 3    [today, world, combat, desertification, drough...
# 4    [hearing, greghunt, confident, vaccines, will,...
# Name: original_text, dtype: object

# %%
#stem the words
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply( lambda x: [stemmer.stem(word) for word in x])

tokenized_tweet.head()
# Out:
# 0    [give, forth, life, becom, burden, kenya, thi,...
# 1    [teenmaar, panja, gabbarsingh, khaleja, kuda, ...
# 2    [chintu, vachina, nizam, kottaru, film, pattin...
# 3    [today, world, combat, desertif, drought, rest...
# 4    [hear, greghunt, confid, vaccin, will, deliv, ...
# Name: original_text, dtype: object

# %%
# Combine the words into a single string

for i in range(len(tokenized_tweet)):
  tokenized_tweet[i] = " ".join(tokenized_tweet[i])

df['original_text'] = tokenized_tweet
df.head()
# Out:
#                                        original_text  ...  scoremap
# 0  give forth life becom burden kenya thi mother ...  ...  Negative
# 1  teenmaar panja gabbarsingh khaleja kuda varaku...  ...   Neutral
# 2  chintu vachina nizam kottaru film pattinndhi i...  ...   Neutral
# 3  today world combat desertif drought restor deg...  ...  Positive
# 4  hear greghunt confid vaccin will deliv like he...  ...  Positive
#
# [5 rows x 4 columns]

# %% [markdown]
# ## EDA

# %%
#Vusualizations Plot World Cloud
plt.figure(figsize = (12,10))
from wordcloud import WordCloud
allwords = ' '.join( [twts for twts in df['original_text']])
wordCloud = WordCloud(width = 800, height = 500, random_state = 42 , max_font_size = 100).generate(allwords)


plt.imshow(wordCloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
score_code = {'Positive': 1, 'Negative': 0}
df['scoremap'] = df['scoremap'].map(score_code)
df = df.dropna()
df.head()
# Out:
#                                        original_text  ...  scoremap
# 0  give forth life becom burden kenya thi mother ...  ...       0.0
# 3  today world combat desertif drought restor deg...  ...       1.0
# 4  hear greghunt confid vaccin will deliv like he...  ...       1.0
# 6  today world combat desertif drought restor deg...  ...       1.0
# 8  deploy carbon technolog need taken massiv scal...  ...       1.0
#
# [5 rows x 4 columns]

# %% [markdown]
# ## INPUT SPLIT

# %%
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df = 0.90,min_df = 2,max_features = 1000,stop_words = 'english')
bow = bow_vectorizer.fit_transform(df['original_text'])

# %%
mat = bow[0].toarray()
df.head()
# Out:
#                                        original_text  ...  scoremap
# 0  give forth life becom burden kenya thi mother ...  ...       0.0
# 3  today world combat desertif drought restor deg...  ...       1.0
# 4  hear greghunt confid vaccin will deliv like he...  ...       1.0
# 6  today world combat desertif drought restor deg...  ...       1.0
# 8  deploy carbon technolog need taken massiv scal...  ...       1.0
#
# [5 rows x 4 columns]

# %% [markdown]
# ## MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(bow,df['scoremap'],random_state = 42, test_size = 0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import f1_score, accuracy_score

# %%
# Training

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#testing 
pred = model.predict(X_test)
print ('The f1_score = : ' ,f1_score(y_test,pred))
print ('The accuracy_score = : ' ,accuracy_score(y_test,pred))
# Out:
# The f1_score = :  0.9792531120331951
# The accuracy_score = :  0.9704840613931524

# %%
#Use probability to get the output
pred_prob = model.predict_proba(X_test)
pred = pred_prob[:,1]>= 0.3
pred = pred.astype(np.int)

print ('The f1_score = : ' ,f1_score(y_test,pred))
print ('The accuracy_score = : ' ,accuracy_score(y_test,pred))
# Out:
# The f1_score = :  0.9739837398373983
# The accuracy_score = :  0.9622195985832349

# %%
pred_prob[0][1] >= 0.3
# Out:
# True

# %% [markdown]
# ## SGDClassifier

# %%
model1 = SGDClassifier()
model1.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
#testing 
pred = model1.predict(X_test)
print ('The f1_score = : ' ,f1_score(y_test,pred))
print ('The accuracy_score = : ' ,accuracy_score(y_test,pred))
# Out:
# The f1_score = :  0.9849498327759197
# The accuracy_score = :  0.9787485242030697
